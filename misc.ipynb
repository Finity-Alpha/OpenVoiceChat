# %%
import OpenVoiceChat as ovc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import OpenVoiceChat as ovc
#
# ModuleNotFoundError: No module named 'OpenVoiceChat'

# %%
import OpenVoiceChat as ovc
import OpenVoiceChat.llm as llm
chatbot = llm.llm_llama.Chatbot_llama(sys_prompt='hello')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import OpenVoiceChat as ovc
#       2 import OpenVoiceChat.llm as llm
#       3 chatbot = llm.llm_llama.Chatbot_llama(sys_prompt='hello')
#
# ModuleNotFoundError: No module named 'OpenVoiceChat'

# %%
ovc.llm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ovc.llm
#
# AttributeError: module 'OpenVoiceChat' has no attribute 'llm'

# %%
ovc.llm.llm_gpt.Chatbot_gpt(sys_prompt='hello')

# %%
from ovc.llm import llm_gpt

# %%
# from ovc.llm.llm_gpt import Chatbot_gpt
# import llm.llm_gpt as llm_gpt
# import ovc.llm

# %%
# obj = llm_gpt.Chatbot_gpt(sys_prompt='hello')
